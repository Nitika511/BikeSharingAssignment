# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("BikeSharing.csv")
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df.shape
# Out:
# (730, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %% [markdown]
# #### Looking at the dataframe info above, we can see that there are no null entries.

# %% [markdown]
# #### Lets map some columns for meaningful interpretation

# %%
# Month values to String

df['mnth'] = df['mnth'].map({1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June', 7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'})
df.head()
# Out:
#    instant      dteday  season  yr     mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0  January        0        6           0
# 1        2  02-01-2018       1   0  January        0        0           0
# 2        3  03-01-2018       1   0  January        0        1           1
# 3        4  04-01-2018       1   0  January        0        2           1
# 4        5  05-01-2018       1   0  January        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# Season values to String

df['season'] = df['season'].map({1:'spring', 2:'summer', 3:'fall', 4:'winter'})
df.head()
# Out:
#    instant      dteday  season  yr     mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018  spring   0  January        0        6           0
# 1        2  02-01-2018  spring   0  January        0        0           0
# 2        3  03-01-2018  spring   0  January        0        1           1
# 3        4  04-01-2018  spring   0  January        0        2           1
# 4        5  05-01-2018  spring   0  January        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# Weather values to String
df['weather'] = df['weathersit'].map({1:'Partly Cloudy', 2:'Misty Cloudy', 3:'Light Snow Rain', 4:'Heavy Rain Snow'})
df.drop('weathersit', axis=1, inplace=True)
df.head()
# Out:
#    instant      dteday  season  yr     mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018  spring   0  January        0        6           0
# 1        2  02-01-2018  spring   0  January        0        0           0
# 2        3  03-01-2018  spring   0  January        0        1           1
# 3        4  04-01-2018  spring   0  January        0        2           1
# 4        5  05-01-2018  spring   0  January        0        3           1
#
#         temp     atemp      hum  windspeed  casual  registered   cnt  \
# 0  14.110847  18.18125  80.5833  10.749882     331         654   985
# 1  14.902598  17.68695  69.6087  16.652113     131         670   801
# 2   8.050924   9.47025  43.7273  16.636703     120        1229  1349
# 3   8.200000  10.60610  59.0435  10.739832     108        1454  1562
# 4   9.305237  11.46350  43.6957  12.522300      82        1518  1600
#
#          weather
# 0   Misty Cloudy
# 1   Misty Cloudy
# 2  Partly Cloudy
# 3  Partly Cloudy
# 4  Partly Cloudy

# %%
# weekday, workingday and holiday columns are trying to explain the same thing i.e. whether it was an off from work or not
# It makes sense to combine them into one derived metric which shows whether it was a working or a non-working day. 
def calculateWorkingNonWorking(df):
    if(df.workingday == 0):
        return 0
    elif(df.weekday == 0 or df.weekday == 6):
        return 0
    elif(df.holiday==1):
        return 0
    return 1

# %%
df['working'] = df.apply(calculateWorkingNonWorking, axis=1)
df.head()
# Out:
#    instant      dteday  season  yr     mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018  spring   0  January        0        6           0
# 1        2  02-01-2018  spring   0  January        0        0           0
# 2        3  03-01-2018  spring   0  January        0        1           1
# 3        4  04-01-2018  spring   0  January        0        2           1
# 4        5  05-01-2018  spring   0  January        0        3           1
#
#         temp     atemp      hum  windspeed  casual  registered   cnt  \
# 0  14.110847  18.18125  80.5833  10.749882     331         654   985
# 1  14.902598  17.68695  69.6087  16.652113     131         670   801
# 2   8.050924   9.47025  43.7273  16.636703     120        1229  1349
# 3   8.200000  10.60610  59.0435  10.739832     108        1454  1562
# 4   9.305237  11.46350  43.6957  12.522300      82        1518  1600
#
#          weather  working
# 0   Misty Cloudy        0
# 1   Misty Cloudy        0
# 2  Partly Cloudy        1
# 3  Partly Cloudy        1
# 4  Partly Cloudy        1

# %%
# Drop the columns not needed for analysis
df = df.drop(['holiday','weekday','workingday'], axis=1)
df.head()
# Out:
#    instant      dteday  season  yr     mnth       temp     atemp      hum  \
# 0        1  01-01-2018  spring   0  January  14.110847  18.18125  80.5833
# 1        2  02-01-2018  spring   0  January  14.902598  17.68695  69.6087
# 2        3  03-01-2018  spring   0  January   8.050924   9.47025  43.7273
# 3        4  04-01-2018  spring   0  January   8.200000  10.60610  59.0435
# 4        5  05-01-2018  spring   0  January   9.305237  11.46350  43.6957
#
#    windspeed  casual  registered   cnt        weather  working
# 0  10.749882     331         654   985   Misty Cloudy        0
# 1  16.652113     131         670   801   Misty Cloudy        0
# 2  16.636703     120        1229  1349  Partly Cloudy        1
# 3  10.739832     108        1454  1562  Partly Cloudy        1
# 4  12.522300      82        1518  1600  Partly Cloudy        1

# %% [markdown]
# ### Univariate Analysis

# %%
# lets look at basic corelation of the available numerical columns on our target variable "cnt" first.

# %%
# We will see the share of casual and registered bikes usages
casSum = np.sum(df.casual)
regSum = np.sum(df.registered)
arr = [casSum, regSum]

plt.pie(x = arr, labels=['Casual','Registered'], autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
# mnth to cnt
sns.lineplot(x= df.mnth, y = df.cnt, data = df)
plt.xticks(rotation=90)
plt.show()

# It seems the demand is highest during the months of May - October i.e. during the season of Summer, Fall and Winter, but not in spring and early summer

# %%
sns.barplot(x = df.mnth, y = df.cnt, data = df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x = df.weather, y = df.cnt, data = df)
plt.show()

# So the count is highest in weather condition "Clear, Few clouds, Partly cloudy", 
# still ok in "Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist"
# But remarkably drops in more severe weather conditions like snow and heavy rain

# %%
# Now lets see the impact of temperatures on demand

sns.scatterplot(x = df['atemp'], y = df.cnt, data=df)
plt.show()

# We clearly see a co-relation between temperature and demand. 
# As temperature increases upto 30 degree celsius, demand grows, but starts dropping therafter

# %%
# Seasons vs demand

sns.barplot(x = df.season, y = df.cnt, data = df)
plt.show()

# Demand is highest in fall and summer, least in spring

# %%
# Year vs Demand

sns.barplot(x = df['yr'], y = df['cnt'], data=df)
plt.show()

# Demand is significantly high in year 2019 as compared to 2018

# %%
# windspeed vs demand

sns.scatterplot(x = df['windspeed'], y = df.cnt, data=df)
plt.show()

# We can say that demand remains high between wind speeds of 5 - 15 kmph

# %% [markdown]
# ### Building the model

# %%
import statsmodels.api as sm

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'temp', 'atemp', 'hum',
#        'windspeed', 'casual', 'registered', 'cnt', 'weather', 'working'],
#       dtype='object')

# %%
# Using only the columns which seem to be useful for analysis

df1 = df[['season','yr','mnth','atemp','hum','windspeed','weather','working','cnt']]
df1.head()
# Out:
#    season  yr     mnth     atemp      hum  windspeed        weather  working  \
# 0  spring   0  January  18.18125  80.5833  10.749882   Misty Cloudy        0
# 1  spring   0  January  17.68695  69.6087  16.652113   Misty Cloudy        0
# 2  spring   0  January   9.47025  43.7273  16.636703  Partly Cloudy        1
# 3  spring   0  January  10.60610  59.0435  10.739832  Partly Cloudy        1
# 4  spring   0  January  11.46350  43.6957  12.522300  Partly Cloudy        1
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# #### Dummy variables needed for columns

# %%
# Dummy for weather

dummy_for_weather = pd.get_dummies(df1['weather'], dtype=int, drop_first=True)
df1 = pd.concat([df1, dummy_for_weather], axis=1)
df1.head()
# Out:
#    season  yr     mnth     atemp      hum  windspeed        weather  working  \
# 0  spring   0  January  18.18125  80.5833  10.749882   Misty Cloudy        0
# 1  spring   0  January  17.68695  69.6087  16.652113   Misty Cloudy        0
# 2  spring   0  January   9.47025  43.7273  16.636703  Partly Cloudy        1
# 3  spring   0  January  10.60610  59.0435  10.739832  Partly Cloudy        1
# 4  spring   0  January  11.46350  43.6957  12.522300  Partly Cloudy        1
#
#     cnt  Misty Cloudy  Partly Cloudy
# 0   985             1              0
# 1   801             1              0
# 2  1349             0              1
# 3  1562             0              1
# 4  1600             0              1

# %%
# Dummy for season

dummy_for_season = pd.get_dummies(df1['season'], dtype=int, drop_first=True)
df1 = pd.concat([df1, dummy_for_season], axis=1)
df1.head()
# Out:
#    season  yr     mnth     atemp      hum  windspeed        weather  working  \
# 0  spring   0  January  18.18125  80.5833  10.749882   Misty Cloudy        0
# 1  spring   0  January  17.68695  69.6087  16.652113   Misty Cloudy        0
# 2  spring   0  January   9.47025  43.7273  16.636703  Partly Cloudy        1
# 3  spring   0  January  10.60610  59.0435  10.739832  Partly Cloudy        1
# 4  spring   0  January  11.46350  43.6957  12.522300  Partly Cloudy        1
#
#     cnt  Misty Cloudy  Partly Cloudy  spring  summer  winter
# 0   985             1              0       1       0       0
# 1   801             1              0       1       0       0
# 2  1349             0              1       1       0       0
# 3  1562             0              1       1       0       0
# 4  1600             0              1       1       0       0

# %%
df.head()
# Out:
#    instant      dteday  season  yr     mnth       temp     atemp      hum  \
# 0        1  01-01-2018  spring   0  January  14.110847  18.18125  80.5833
# 1        2  02-01-2018  spring   0  January  14.902598  17.68695  69.6087
# 2        3  03-01-2018  spring   0  January   8.050924   9.47025  43.7273
# 3        4  04-01-2018  spring   0  January   8.200000  10.60610  59.0435
# 4        5  05-01-2018  spring   0  January   9.305237  11.46350  43.6957
#
#    windspeed  casual  registered   cnt        weather  working
# 0  10.749882     331         654   985   Misty Cloudy        0
# 1  16.652113     131         670   801   Misty Cloudy        0
# 2  16.636703     120        1229  1349  Partly Cloudy        1
# 3  10.739832     108        1454  1562  Partly Cloudy        1
# 4  12.522300      82        1518  1600  Partly Cloudy        1

# %% [markdown]
# #### Dummy for month
# #### Month has 12 unique values, if we create dummy for month, we would get 11 new columns and might make the model complicated.
# #### Also, as per real world scenario, month should also be co-related with season and weather. Hence not using month in my model.

# %%
df1 = df1.drop(['weather', 'season','mnth'], axis=1)
df1.head()
# Out:
#    yr     atemp      hum  windspeed  working   cnt  Misty Cloudy  \
# 0   0  18.18125  80.5833  10.749882        0   985             1
# 1   0  17.68695  69.6087  16.652113        0   801             1
# 2   0   9.47025  43.7273  16.636703        1  1349             0
# 3   0  10.60610  59.0435  10.739832        1  1562             0
# 4   0  11.46350  43.6957  12.522300        1  1600             0
#
#    Partly Cloudy  spring  summer  winter
# 0              0       1       0       0
# 1              0       1       0       0
# 2              1       1       0       0
# 3              1       1       0       0
# 4              1       1       0       0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   yr             730 non-null    int64
#  1   atemp          730 non-null    float64
#  2   hum            730 non-null    float64
#  3   windspeed      730 non-null    float64
#  4   working        730 non-null    int64
#  5   cnt            730 non-null    int64
#  6   Misty Cloudy   730 non-null    int32
#  7   Partly Cloudy  730 non-null    int32
#  8   spring         730 non-null    int32
#  9   summer         730 non-null    int32
#  10  winter         730 non-null    int32
# dtypes: float64(3), int32(5), int64(3)
# memory usage: 48.6 KB

# %%
# Creating a pairplot

sns.pairplot(df1[['cnt','atemp','hum','windspeed']])
plt.show()

# Below pairplot show that the temperature and cnt variable has the strongest linear relationship.

# %%
# Correlation matrix of all columns

plt.figure(figsize = (16, 10))
sns.heatmap(df1.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
df1.columns
# Out:
# Index(['yr', 'atemp', 'hum', 'windspeed', 'working', 'cnt', 'Misty Cloudy',
#        'Partly Cloudy', 'spring', 'summer', 'winter'],
#       dtype='object')

# %%
# From the above co-relation matrix we will pick the variables with highest co-relation co-efficients for our first model

df2 = df1[['yr','atemp','windspeed','Misty Cloudy', 'Partly Cloudy', 'spring', 'summer', 'winter', 'cnt']]

# %%
df2.head()
# Out:
#    yr     atemp  windspeed  Misty Cloudy  Partly Cloudy  spring  summer  \
# 0   0  18.18125  10.749882             1              0       1       0
# 1   0  17.68695  16.652113             1              0       1       0
# 2   0   9.47025  16.636703             0              1       1       0
# 3   0  10.60610  10.739832             0              1       1       0
# 4   0  11.46350  12.522300             0              1       1       0
#
#    winter   cnt
# 0       0   985
# 1       0   801
# 2       0  1349
# 3       0  1562
# 4       0  1600

# %% [markdown]
# ### Splitting the Data into Training and Testing Sets

# %%
from sklearn.model_selection import train_test_split

# We specify this so that the train and test data set always have the same rows, respectively
np.random.seed(0)
df_train, df_test = train_test_split(df2, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
df_train.columns
# Out:
# Index(['yr', 'atemp', 'windspeed', 'Misty Cloudy', 'Partly Cloudy', 'spring',
#        'summer', 'winter', 'cnt'],
#       dtype='object')

# %%
print(df_train.shape, df_test.shape)
# Out:
# (510, 9) (219, 9)

# %% [markdown]
# ### Rescaling the train set

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
# Using MinMaxScaler we are scaling the numerical columns aTemp and windspeed in values between 0 and 1, so that model co-efficients are 
# interpreted correctly.

df_train[['atemp', 'windspeed']] = scaler.fit_transform(df_train[['atemp', 'windspeed']])
df_train.head()
# Out:
#      yr     atemp  windspeed  Misty Cloudy  Partly Cloudy  spring  summer  \
# 653   1  0.501133   0.300794             0              1       0       0
# 576   1  0.766351   0.264686             0              1       0       0
# 426   1  0.438975   0.255342             1              0       1       0
# 728   1  0.200348   0.663106             0              1       1       0
# 482   1  0.391735   0.188475             1              0       0       1
#
#      winter   cnt
# 653       1  7534
# 576       0  7216
# 426       0  4066
# 728       0  1796
# 482       0  4220

# %% [markdown]
# ### Dividing into X and Y train sets for model building

# %%
y_train = df_train.pop('cnt')
X_train = df_train

# %%
import statsmodels.api as sm

X_train_lm = sm.add_constant(X_train)
X_train_lm
# Out:
#      const  yr     atemp  windspeed  Misty Cloudy  Partly Cloudy  spring  \
# 653    1.0   1  0.501133   0.300794             0              1       0
# 576    1.0   1  0.766351   0.264686             0              1       0
# 426    1.0   1  0.438975   0.255342             1              0       1
# 728    1.0   1  0.200348   0.663106             0              1       1
# 482    1.0   1  0.391735   0.188475             1              0       0
# ..     ...  ..       ...        ...           ...            ...     ...
# 526    1.0   1  0.762183   0.355596             1              0       0
# 578    1.0   1  0.824359   0.187140             0              1       0
# 53     1.0   0  0.218747   0.111379             0              1       1
# 350    1.0   0  0.223544   0.431816             1              0       0
# 79     1.0   0  0.434043   0.529881             1              0       0
#
#      summer  winter
# 653       0       1
# 576       0       0
# 426       0       0
# 728       0       0
# 482       1       0
# ..      ...     ...
# 526       1       0
# 578       0       0
# 53        0       0
# 350       0       1
# 79        1       0
#
# [510 rows x 9 columns]

# %%
# Create a first fitted model
lr_1 = sm.OLS(y_train, X_train_lm).fit()
lr_1.params
# Out:
# const            -261.718951
# yr               2048.280124
# atemp            4045.545282
# windspeed       -1205.841407
# Misty Cloudy     1709.940191
# Partly Cloudy    2366.976189
# spring           -909.102381
# summer            207.157742
# winter            472.766529
# dtype: float64

# %%
print(lr_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.813
# Method:                 Least Squares   F-statistic:                     277.0
# Date:                Sun, 25 Aug 2024   Prob (F-statistic):          1.74e-178
# Time:                        16:04:51   Log-Likelihood:                -4156.2
# No. Observations:                 510   AIC:                             8330.
# Df Residuals:                     501   BIC:                             8368.
# Df Model:                           8
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          -261.7190    333.838     -0.784      0.433    -917.613     394.175
# yr             2048.2801     75.502     27.129      0.000    1899.941    2196.620
# atemp          4045.5453    307.500     13.156      0.000    3441.397    4649.693
# windspeed     -1205.8414    231.286     -5.214      0.000   -1660.252    -751.431
# Misty Cloudy   1709.9402    230.421      7.421      0.000    1257.230    2162.650
# Partly Cloudy  2366.9762    226.617     10.445      0.000    1921.739    2812.213
# spring         -909.1024    177.050     -5.135      0.000   -1256.954    -561.251
# summer          207.1577    120.483      1.719      0.086     -29.557     443.872
# winter          472.7665    142.015      3.329      0.001     193.748     751.785
# ==============================================================================
# Omnibus:                       72.769   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              199.805
# Skew:                          -0.698   Prob(JB):                     4.10e-44
# Kurtosis:                       5.730   Cond. No.                         19.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### According to above summary, summar has a high P-value of > 0.05 . Lets look at VIFs of all variables

# %% [markdown]
# ### Analyzing VIF for all variables

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#         Features    VIF
# 4  Partly Cloudy  13.76
# 1          atemp  11.32
# 3   Misty Cloudy   7.66
# 2      windspeed   4.51
# 5         spring   3.58
# 7         winter   2.30
# 6         summer   2.15
# 0             yr   2.07

# %%
# So we see above that weather 'Partly Cloudy' has the highest VIF. Lets drop this first to see the effect on our model results

X = X_train.drop('Partly Cloudy', axis=1)
X_train_lm = sm.add_constant(X)
X_train_lm
# Out:
#      const  yr     atemp  windspeed  Misty Cloudy  spring  summer  winter
# 653    1.0   1  0.501133   0.300794             0       0       0       1
# 576    1.0   1  0.766351   0.264686             0       0       0       0
# 426    1.0   1  0.438975   0.255342             1       1       0       0
# 728    1.0   1  0.200348   0.663106             0       1       0       0
# 482    1.0   1  0.391735   0.188475             1       0       1       0
# ..     ...  ..       ...        ...           ...     ...     ...     ...
# 526    1.0   1  0.762183   0.355596             1       0       1       0
# 578    1.0   1  0.824359   0.187140             0       0       0       0
# 53     1.0   0  0.218747   0.111379             0       1       0       0
# 350    1.0   0  0.223544   0.431816             1       0       0       1
# 79     1.0   0  0.434043   0.529881             1       0       1       0
#
# [510 rows x 8 columns]

# %%
lr_2 = sm.OLS(y_train, X_train_lm).fit()

# %%
print(lr_2.summary())

# We see that there is no effect on our R-sqaured or adjusted R-squared values.
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     247.6
# Date:                Sun, 25 Aug 2024   Prob (F-statistic):          2.48e-158
# Time:                        16:05:07   Log-Likelihood:                -4206.4
# No. Observations:                 510   AIC:                             8429.
# Df Residuals:                     502   BIC:                             8463.
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1950.1298    284.508      6.854      0.000    1391.157    2509.102
# yr            2093.6003     83.097     25.195      0.000    1930.339    2256.861
# atemp         4189.3977    338.653     12.371      0.000    3524.045    4854.750
# windspeed    -1436.0813    253.814     -5.658      0.000   -1934.750    -937.413
# Misty Cloudy  -549.4366     87.511     -6.278      0.000    -721.369    -377.504
# spring        -806.4934    194.882     -4.138      0.000   -1189.378    -423.608
# summer         260.7196    132.702      1.965      0.050      -0.001     521.440
# winter         422.7961    156.471      2.702      0.007     115.377     730.216
# ==============================================================================
# Omnibus:                      123.992   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              444.230
# Skew:                          -1.081   Prob(JB):                     3.44e-97
# Kurtosis:                       7.029   Cond. No.                         16.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### So we now see that P-Value of summar has dropped to 0.05 now. Again lets see the VIFs

# %%
# Lets see the VIFs now
vif = pd.DataFrame()
vif['Features'] = X_train_lm.columns
vif['VIF'] = [variance_inflation_factor(X_train_lm.values, i) for i in range(X_train_lm.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Now we see all the VIFs dropped below 4. But still lets try dropping season_1 which has a high VIF of > 4
# Out:
#        Features    VIF
# 0         const  47.58
# 5        spring   4.11
# 2         atemp   3.03
# 7        winter   2.69
# 6        summer   1.92
# 3     windspeed   1.09
# 1            yr   1.01
# 4  Misty Cloudy   1.01

# %%
# Lets drop summer with a high p-value and retrain the model
X = X_train_lm.drop('summer', axis=1)
X_train_lm = sm.add_constant(X)
X_train_lm
# Out:
#      const  yr     atemp  windspeed  Misty Cloudy  spring  winter
# 653    1.0   1  0.501133   0.300794             0       0       1
# 576    1.0   1  0.766351   0.264686             0       0       0
# 426    1.0   1  0.438975   0.255342             1       1       0
# 728    1.0   1  0.200348   0.663106             0       1       0
# 482    1.0   1  0.391735   0.188475             1       0       0
# ..     ...  ..       ...        ...           ...     ...     ...
# 526    1.0   1  0.762183   0.355596             1       0       0
# 578    1.0   1  0.824359   0.187140             0       0       0
# 53     1.0   0  0.218747   0.111379             0       1       0
# 350    1.0   0  0.223544   0.431816             1       0       1
# 79     1.0   0  0.434043   0.529881             1       0       0
#
# [510 rows x 7 columns]

# %%
lr_3 = sm.OLS(y_train, X_train_lm).fit()

print(lr_3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.774
# Model:                            OLS   Adj. R-squared:                  0.771
# Method:                 Least Squares   F-statistic:                     286.6
# Date:                Sun, 25 Aug 2024   Prob (F-statistic):          9.54e-159
# Time:                        16:05:39   Log-Likelihood:                -4208.4
# No. Observations:                 510   AIC:                             8431.
# Df Residuals:                     503   BIC:                             8460.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         2252.4093    239.997      9.385      0.000    1780.889    2723.930
# yr            2098.7910     83.291     25.198      0.000    1935.150    2262.432
# atemp         3888.0121    302.775     12.841      0.000    3293.153    4482.871
# windspeed    -1377.4756    252.770     -5.450      0.000   -1874.092    -880.860
# Misty Cloudy  -543.8608     87.713     -6.200      0.000    -716.190    -371.531
# spring       -1049.4892    151.033     -6.949      0.000   -1346.222    -752.756
# winter         229.8921    122.177      1.882      0.060     -10.149     469.933
# ==============================================================================
# Omnibus:                      124.838   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              437.138
# Skew:                          -1.097   Prob(JB):                     1.19e-95
# Kurtosis:                       6.970   Cond. No.                         13.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif = pd.DataFrame()
vif['Features'] = X_train_lm.columns
vif['VIF'] = [variance_inflation_factor(X_train_lm.values, i) for i in range(X_train_lm.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#        Features    VIF
# 0         const  33.66
# 5        spring   2.45
# 2         atemp   2.41
# 6        winter   1.63
# 3     windspeed   1.07
# 1            yr   1.01
# 4  Misty Cloudy   1.01

# %% [markdown]
# #### We see great improvement in our VIF values now. This means now the variables present in our model dont have multi-collinearity.
# #### However season 'winter' has a high p-value.

# %%
# Lets drop summar with a high p-value and retrain the model
X = X_train_lm.drop('winter', axis=1)
X_train_lm = sm.add_constant(X)
X_train_lm
# Out:
#      const  yr     atemp  windspeed  Misty Cloudy  spring
# 653    1.0   1  0.501133   0.300794             0       0
# 576    1.0   1  0.766351   0.264686             0       0
# 426    1.0   1  0.438975   0.255342             1       1
# 728    1.0   1  0.200348   0.663106             0       1
# 482    1.0   1  0.391735   0.188475             1       0
# ..     ...  ..       ...        ...           ...     ...
# 526    1.0   1  0.762183   0.355596             1       0
# 578    1.0   1  0.824359   0.187140             0       0
# 53     1.0   0  0.218747   0.111379             0       1
# 350    1.0   0  0.223544   0.431816             1       0
# 79     1.0   0  0.434043   0.529881             1       0
#
# [510 rows x 6 columns]

# %%
lr_4 = sm.OLS(y_train, X_train_lm).fit()

print(lr_4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                     341.5
# Date:                Sun, 25 Aug 2024   Prob (F-statistic):          2.85e-159
# Time:                        16:05:56   Log-Likelihood:                -4210.1
# No. Observations:                 510   AIC:                             8432.
# Df Residuals:                     504   BIC:                             8458.
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         2533.4871    188.314     13.454      0.000    2163.510    2903.464
# yr            2103.0435     83.470     25.195      0.000    1939.052    2267.035
# atemp         3569.9210    251.818     14.177      0.000    3075.179    4064.663
# windspeed    -1440.4339    251.177     -5.735      0.000   -1933.916    -946.951
# Misty Cloudy  -549.7602     87.878     -6.256      0.000    -722.412    -377.108
# spring       -1216.4451    122.529     -9.928      0.000   -1457.175    -975.715
# ==============================================================================
# Omnibus:                      114.439   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              374.950
# Skew:                          -1.025   Prob(JB):                     3.81e-82
# Kurtosis:                       6.667   Cond. No.                         10.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Residual Analysis of the train data

# %%
y_train_cnt = lr_4.predict(X_train_lm)

# %%
fig = plt.figure()
sns.distplot((y_train - y_train_cnt), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 18)
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# #### We can see clearly from above distplot that the error terms are normally distributed.
# #### This means that the model is working well with these variables and there no particular pattern and skewness which can be improved by
# #### removing/adding any variables.

# %% [markdown]
# ### Predicting using model 4

# %%
df_test
# Out:
#      yr     atemp  windspeed  Misty Cloudy  Partly Cloudy  spring  summer  \
# 184   0  33.27085   5.459106             1              0       0       0
# 535   1  36.04875   7.625404             0              1       0       1
# 299   0  22.85230  13.250121             1              0       0       0
# 221   0  34.24915  13.417286             0              1       0       0
# 152   0  32.19710  19.583229             0              1       0       1
# ..   ..       ...        ...           ...            ...     ...     ...
# 400   1  13.22605  11.791732             1              0       1       0
# 702   1  23.45270  11.666643             0              1       0       0
# 127   0  25.94665   5.000712             0              1       0       1
# 640   1  29.95665   4.458569             1              0       0       0
# 72    0  16.60000   9.174042             0              1       1       0
#
#      winter   cnt
# 184       0  6043
# 535       0  6211
# 299       1  2659
# 221       0  4780
# 152       0  4968
# ..      ...   ...
# 400       0  2947
# 702       1  6606
# 127       0  4333
# 640       1  7572
# 72        0  2046
#
# [219 rows x 9 columns]

# %%
df_test[['atemp', 'windspeed']] = scaler.transform(df_test[['atemp', 'windspeed']])
df_test.head()
# Out:
#      yr     atemp  windspeed  Misty Cloudy  Partly Cloudy  spring  summer  \
# 184   0  0.769660   0.084219             1              0       0       0
# 535   1  0.842587   0.153728             0              1       0       1
# 299   0  0.496145   0.334206             1              0       0       0
# 221   0  0.795343   0.339570             0              1       0       0
# 152   0  0.741471   0.537414             0              1       0       1
#
#      winter   cnt
# 184       0  6043
# 535       0  6211
# 299       1  2659
# 221       0  4780
# 152       0  4968

# %% [markdown]
# ### Dividing into X_test and y_test

# %%
y_test = df_test.pop('cnt')
X_test = df_test

# %%
X_test_m4 = sm.add_constant(X_test)
X_test_m4 = X_test_m4.drop(['summer','winter','Partly Cloudy'], axis=1)
X_test_m4.head()
# Out:
#      const  yr     atemp  windspeed  Misty Cloudy  spring
# 184    1.0   0  0.769660   0.084219             1       0
# 535    1.0   1  0.842587   0.153728             0       0
# 299    1.0   0  0.496145   0.334206             1       0
# 221    1.0   0  0.795343   0.339570             0       0
# 152    1.0   0  0.741471   0.537414             0       0

# %%
y_pred_m4 = lr_4.predict(X_test_m4)
y_pred_m4
# Out:
# 184    4610.041434
# 535    7423.066829
# 299    3273.524031
# 221    4883.671662
# 152    4406.371814
#           ...
# 400    3325.354503
# 702    6055.783564
# 127    4494.563515
# 640    6448.721447
# 72     2209.264122
# Length: 219, dtype: float64

# %%
fig = plt.figure()
plt.scatter(y_test, y_pred_m4)
fig.suptitle('y_test vs y_pred', fontsize = 20)              # Plot heading 
plt.xlabel('y_test', fontsize = 18)                          # X-label
plt.ylabel('y_pred', fontsize = 16)
# Out:
# Text(0, 0.5, 'y_pred')

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred_m4)
# Out:
# 0.7670868496966449

# %%
### Hence getting a R2_score of 0.76 for the final model.

# %%
# Hence Equation of our Linear Regression model is

yr            2103.0435     83.470     25.195      0.000    1939.052    2267.035
atemp         3569.9210    251.818     14.177      0.000    3075.179    4064.663
windspeed    -1440.4339    251.177     -5.735      0.000   -1933.916    -946.951
Misty Cloudy  -549.7602     87.878     -6.256      0.000    -722.412    -377.108
spring       -1216.4451

# 2533.4871 + 2103.0435*yr + 3569.9210*atemp -1440.4339*windspeed -549.7602*Misty Cloudy -1216.4451*spring

# %% [markdown]
# ### So looking at the co-efficients we see increasing windspeed and harsh weather is reducing the demand for shared bikes.
# ### For temperature, it a positive co-efficient. hence in general, a higher temperature which means less snow/rainfall,
# ### has positive effect on the demand for bikes
